# %% [markdown]
# ## Live Code: Python Dictionary
#
# As we mentioned earlier, one of the most popular forms of python dictionaries you'll run across as you work is through __JSON__ ([JavaScript Object Notation](https://www.json.org/json-en.html)). JSON is the primary format in which data is passed back and forth to APIs ([Application Programming Interface](https://medium.com/@perrysetgo/what-exactly-is-an-api-69f36968a41f)), and most API servers will send their responses in JSON format. Python has great JSON support, with the json package. We won't learn about calling APIs today (*stay tuned for week 6!*) but to get started, we'll play around with a snippet of a call result from the New York Times API.

# %%
# import requests and json - needed to make an API call
import requests
import json

authorized_key = "wuVWLTGSwdIknOmyb5xgYHQf7q2GHaKi" # if you want to play around with the API, please make your own key at https://developer.nytimes.com/
day = str(7) # this particular API requires you to choose from 1, 7, 30 (past day, 7 days, 30 days)

# API url for the most emailed articles over a day, past 7 days or 30 days
# we are getting the results for the past 7 days
api_url = "https://api.nytimes.com/svc/mostpopular/v2/emailed/%s.json?api-key=%s" %(day, authorized_key) 
print(api_url)
# Out:
# https://api.nytimes.com/svc/mostpopular/v2/emailed/7.json?api-key=wuVWLTGSwdIknOmyb5xgYHQf7q2GHaKi

# %%
# calling the API with requests
response = requests.get(api_url)
# creating a variable called data to hold the json formatted result
data = response.json()

# %%
# show raw data
print(type(data))
data
# Out:
# <class 'dict'>
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'uri': 'nyt://article/cf3d51df-5f8b-5ae5-b439-5371f10d56b1',
#    'url': 'https://www.nytimes.com/2020/06/09/well/live/coronavirus-rules-pandemic-infection-prevention.html',
#    'id': 100000007152805,
#    'asset_id': 100000007152805,
#    'source': 'New York Times',
#    'published_date': '2020-06-09',
#    'updated': '2020-06-14 07:12:54',
#    'section': 'Well',
#    'subsection': 'Live',
#    'nytdsection': 'well',
#    'adx_keywords': 'Coronavirus (2019-nCoV);Quarantines;Contact Tracing (Public Health);Tests (Medical);Coronavirus Reopenings;Masks;Hygiene and Cleanliness;Supermarkets and Grocery Stores;Coronavirus Risks and Safety Concerns;Content Type: Service;Disease Rates',
#    'column': None,
#    'byline': 'By Tara Parker-Pope',
#    'type': 'Article',
#    'title': '5 Rules to Live By During a Pandemic',
#    'abstract': 'There’s no playbook for living through a pandemic, so we decided to create one. With some basic rules to guide you, everyone can lower risk and live a full life while we wait for the virus to get under control.',
#    'des_facet': ['Coronavirus (2019-nCoV)',
#     'Quarantines',
#     'Contact Tracing (Public Health)',
#     'Tests (Medical)',
#     'Coronavirus Reopenings',
#     'Masks',
#     'Hygiene and Cleanliness',
#     'Supermarkets and Grocery Stores',
#     'Coronavirus Risks and Safety Concerns',
#     'Content Type: Service',
#     'Disease Rates'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Abby Fisher, a hostess, prepares a table at Lindey’s restaurant in Columbus, Ohio on June 5.',
#      'copyright': 'Maddie McGarvey for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/08/well/well-restaurant/well-restaurant-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/08/well/well-restaurant/well-restaurant-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/08/well/well-restaurant/well-restaurant-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/0582a540-250c-5cfa-abd7-655454d01717',
#    'url': 'https://www.nytimes.com/2020/06/12/arts/music/bob-dylan-rough-and-rowdy-ways.html',
#    'id': 100000007177221,
#    'asset_id': 100000007177221,
#    'source': 'New York Times',
#    'published_date': '2020-06-12',
#    'updated': '2020-06-15 18:43:53',
#    'section': 'Arts',
#    'subsection': 'Music',
#    'nytdsection': 'arts',
#    'adx_keywords': 'Folk Music;Pop and Rock Music;Dylan, Bob',
#    'column': None,
#    'byline': 'By Douglas Brinkley',
#    'type': 'Article',
#    'title': 'Bob Dylan Has a Lot on His Mind',
#    'abstract': 'In a rare interview, the Nobel Prize winner discusses mortality, drawing inspiration from the past, and his new album, “Rough and Rowdy Ways.”',
#    'des_facet': ['Folk Music', 'Pop and Rock Music'],
#    'org_facet': [],
#    'per_facet': ['Dylan, Bob'],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Bob Dylan&rsquo;s &ldquo;Rough and Rowdy Ways&rdquo; is his first album of original songs since 2012.',
#      'copyright': 'Kevin Winter/Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/433a81c5-21c9-5421-88d1-ab2e06a0bb28',
#    'url': 'https://www.nytimes.com/2020/06/11/books/coronavirus-library-reopening.html',
#    'id': 100000007170335,
#    'asset_id': 100000007170335,
#    'source': 'New York Times',
#    'published_date': '2020-06-11',
#    'updated': '2020-06-14 23:35:14',
#    'section': 'Books',
#    'subsection': '',
#    'nytdsection': 'books',
#    'adx_keywords': 'Libraries and Librarians;Shutdowns (Institutional);Books and Literature;Computers and the Internet;Coronavirus Reopenings;Coronavirus (2019-nCoV)',
#    'column': None,
#    'byline': 'By Elizabeth A. Harris',
#    'type': 'Article',
#    'title': 'Libraries Strive to Stay ‘Community Living Rooms’ as They Reopen',
#    'abstract': 'Safely lending books is just the beginning. Libraries are figuring out everything from how to remain welcoming spaces to how to respond to changing reader behavior.',
#    'des_facet': ['Libraries and Librarians',
#     'Shutdowns (Institutional)',
#     'Books and Literature',
#     'Computers and the Internet',
#     'Coronavirus Reopenings',
#     'Coronavirus (2019-nCoV)'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Ridgeway Burns, working for the Hinsdale Public Library in Illinois, is delivering books by bike during the pandemic.',
#      'copyright': 'Lyndon French for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/15/books/00viruslibrary1/00viruslibrary1-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/15/books/00viruslibrary1/00viruslibrary1-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/15/books/00viruslibrary1/00viruslibrary1-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/025e2891-057d-5f4c-8c84-604c088f13a2',
#    'url': 'https://www.nytimes.com/2020/06/15/opinion/coronavirus-college-safe.html',
#    'id': 100000007185873,
#    'asset_id': 100000007185873,
#    'source': 'New York Times',
#    'published_date': '2020-06-15',
#    'updated': '2020-06-16 10:55:03',
#    'section': 'Opinion',
#    'subsection': '',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'Colleges and Universities;Coronavirus (2019-nCoV);Coronavirus Reopenings;Age, Chronological;Youth;Coronavirus Risks and Safety Concerns;United States',
#    'column': None,
#    'byline': 'By Laurence Steinberg',
#    'type': 'Article',
#    'title': 'Expecting Students to Play It Safe if Colleges Reopen Is a Fantasy',
#    'abstract': 'Safety plans border on delusional and could lead to outbreaks of Covid-19 among students, faculty and staff.',
#    'des_facet': ['Colleges and Universities',
#     'Coronavirus (2019-nCoV)',
#     'Coronavirus Reopenings',
#     'Age, Chronological',
#     'Youth',
#     'Coronavirus Risks and Safety Concerns'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['United States'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Students on the campus of Columbia University in March.',
#      'copyright': 'Hiroko Masuike/The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/16/opinion/15steinbergWeb/15steinbergWeb-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/opinion/15steinbergWeb/merlin_170402568_075aac78-e234-4bb4-a460-a53fbda9709d-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/opinion/15steinbergWeb/merlin_170402568_075aac78-e234-4bb4-a460-a53fbda9709d-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/9e560419-578d-5ed8-8643-33ca1fc7bbb5',
#    'url': 'https://www.nytimes.com/2020/06/12/opinion/nyt-tom-cotton-oped-liberalism.html',
#    'id': 100000007184689,
#    'asset_id': 100000007184689,
#    'source': 'New York Times',
#    'published_date': '2020-06-12',
#    'updated': '2020-06-12 22:41:23',
#    'section': 'Opinion',
#    'subsection': '',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'George Floyd Protests (2020);Discrimination;Demonstrations, Protests and Riots;#MeToo Movement;Colleges and Universities;Bennet, James;Biden, Joseph R Jr;Cotton, Tom;Floyd, George (d 2020);DiAngelo, Robin (Author);Kendi, Ibram X;Trump, Donald J;Democratic Party;Republican Party',
#    'column': None,
#    'byline': 'By Ross Douthat',
#    'type': 'Article',
#    'title': 'Ross Douthat: The Tom Cotton Op-Ed and the Cultural Revolution',
#    'abstract': 'How liberalism, and the liberal media, are changing before our eyes.',
#    'des_facet': ['George Floyd Protests (2020)',
#     'Discrimination',
#     'Demonstrations, Protests and Riots',
#     '#MeToo Movement',
#     'Colleges and Universities'],
#    'org_facet': ['Democratic Party', 'Republican Party'],
#    'per_facet': ['Bennet, James',
#     'Biden, Joseph R Jr',
#     'Cotton, Tom',
#     'Floyd, George (d 2020)',
#     'DiAngelo, Robin (Author)',
#     'Kendi, Ibram X',
#     'Trump, Donald J'],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marching in Brooklyn on Saturday to protest police brutality.',
#      'copyright': 'Demetrius Freeman for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/11/opinion/11douthat1/11douthat1-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/11/opinion/11douthat1/merlin_173303679_931b6ee2-07ba-4ac6-8521-47cc552fc5bd-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/11/opinion/11douthat1/merlin_173303679_931b6ee2-07ba-4ac6-8521-47cc552fc5bd-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/1dbe45c0-1cb4-54e9-9c77-e6b6c17745fe',
#    'url': 'https://www.nytimes.com/2020/06/12/world/americas/coronavirus-peru-inequality-corruption.html',
#    'id': 100000007186115,
#    'asset_id': 100000007186115,
#    'source': 'New York Times',
#    'published_date': '2020-06-12',
#    'updated': '2020-06-13 15:13:37',
#    'section': 'World',
#    'subsection': 'Americas',
#    'nytdsection': 'world',
#    'adx_keywords': 'Coronavirus (2019-nCoV);Economic Conditions and Trends;Politics and Government;Income Inequality;Corruption (Institutional);Deaths (Fatalities);Shutdowns (Institutional);Quarantines;Vizcarra, Martin;Peru',
#    'column': None,
#    'byline': 'By Mitra Taj and Anatoly Kurmanaev',
#    'type': 'Article',
#    'title': 'Virus Exposes Weak Links in Peru’s Success Story',
#    'abstract': 'Deep-rooted inequality and graft have thwarted the steps Peru took to prepare for its response to the pandemic.',
#    'des_facet': ['Coronavirus (2019-nCoV)',
#     'Economic Conditions and Trends',
#     'Politics and Government',
#     'Income Inequality',
#     'Corruption (Institutional)',
#     'Deaths (Fatalities)',
#     'Shutdowns (Institutional)',
#     'Quarantines'],
#    'org_facet': [],
#    'per_facet': ['Vizcarra, Martin'],
#    'geo_facet': ['Peru'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Relatives carrying the coffin of a suspected Covid-19 victim at a cemetery on the southern outskirts of Lima last month.',
#      'copyright': 'Ernesto Benavides/Agence France-Presse — Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/11/world/00Virus-Peru/00Virus-Peru-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/11/world/00Virus-Peru/00Virus-Peru-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/11/world/00Virus-Peru/00Virus-Peru-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/d255055d-6990-524e-bbfd-dd90d9179460',
#    'url': 'https://www.nytimes.com/2020/06/13/opinion/sunday/women-leaders-coronavirus.html',
#    'id': 100000007189054,
#    'asset_id': 100000007189054,
#    'source': 'New York Times',
#    'published_date': '2020-06-13',
#    'updated': '2020-06-15 12:11:26',
#    'section': 'Opinion',
#    'subsection': 'Sunday Review',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'Women and Girls;Politics and Government;Coronavirus (2019-nCoV);Deaths (Fatalities);Quarantines;United States Politics and Government;Trump, Donald J',
#    'column': None,
#    'byline': 'By Nicholas Kristof',
#    'type': 'Article',
#    'title': 'What the Pandemic Reveals About the Male Ego',
#    'abstract': 'Why are the rates of coronavirus deaths far lower in many female-led countries?',
#    'des_facet': ['Women and Girls',
#     'Politics and Government',
#     'Coronavirus (2019-nCoV)',
#     'Deaths (Fatalities)',
#     'Quarantines',
#     'United States Politics and Government'],
#    'org_facet': [],
#    'per_facet': ['Trump, Donald J'],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'President Tsai Ing-wen of Taiwan at a military base this spring amid the coronavirus pandemic.',
#      'copyright': 'Ritchie B. Tongo/EPA, via Shutterstock',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/15/opinion/sunday/15Kristof2/14Kristof2-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/15/opinion/sunday/15Kristof2/merlin_171421221_ec3ba2ca-4f93-47c8-9727-f5ad9ab7f258-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/15/opinion/sunday/15Kristof2/merlin_171421221_ec3ba2ca-4f93-47c8-9727-f5ad9ab7f258-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/ccf4a9d3-568f-5b05-84c5-ae685acd47b7',
#    'url': 'https://www.nytimes.com/2020/06/15/us/gay-transgender-workers-supreme-court.html',
#    'id': 100000007069961,
#    'asset_id': 100000007069961,
#    'source': 'New York Times',
#    'published_date': '2020-06-15',
#    'updated': '2020-06-16 23:26:21',
#    'section': 'U.S.',
#    'subsection': '',
#    'nytdsection': 'u.s.',
#    'adx_keywords': 'Discrimination;Homosexuality and Bisexuality;Workplace Hazards and Violations;Transgender and Transsexuals;Civil Rights and Liberties;Decisions and Verdicts;Law and Legislation;Gorsuch, Neil M;Alito, Samuel A Jr;Stephens, Aimee;Bostock, Gerald;Zarda, Donald (1970-2014);Supreme Court (US);Equal Employment Opportunity Commission;RG & GR Harris Funeral Homes Inc',
#    'column': None,
#    'byline': 'By Adam Liptak',
#    'type': 'Article',
#    'title': 'Civil Rights Law Protects Gay and Transgender Workers, Supreme Court Rules',
#    'abstract': 'The court said the language of the Civil Rights Act of 1964, which prohibits sex discrimination, applies to discrimination based on sexual orientation and gender identity.',
#    'des_facet': ['Discrimination',
#     'Homosexuality and Bisexuality',
#     'Workplace Hazards and Violations',
#     'Transgender and Transsexuals',
#     'Civil Rights and Liberties',
#     'Decisions and Verdicts',
#     'Law and Legislation'],
#    'org_facet': ['Supreme Court (US)',
#     'Equal Employment Opportunity Commission',
#     'RG & GR Harris Funeral Homes Inc'],
#    'per_facet': ['Gorsuch, Neil M',
#     'Alito, Samuel A Jr',
#     'Stephens, Aimee',
#     'Bostock, Gerald',
#     'Zarda, Donald (1970-2014)'],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Tiffany Munroe on Sunday in Brooklyn during a rally to call attention to violence against transgender people of color.',
#      'copyright': 'Demetrius Freeman for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/15/us/politics/15dc-scotus-lgbt/15dc-scotus-lgbt-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/15/us/politics/15dc-scotus-lgbt/merlin_173534901_83f3865e-6ba4-4f1b-8d6c-a7f54db8cce8-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/15/us/politics/15dc-scotus-lgbt/merlin_173534901_83f3865e-6ba4-4f1b-8d6c-a7f54db8cce8-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/9ec9a593-a171-5336-ae8b-30620b6e3b42',
#    'url': 'https://www.nytimes.com/2020/06/08/opinion/george-floyd-protests-race.html',
#    'id': 100000007176565,
#    'asset_id': 100000007176565,
#    'source': 'New York Times',
#    'published_date': '2020-06-08',
#    'updated': '2020-06-09 15:39:01',
#    'section': 'Opinion',
#    'subsection': '',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'George Floyd Protests (2020);Black Lives Matter Movement;Police Brutality, Misconduct and Shootings;Criminal Justice;Black People;Race and Ethnicity;Budgets and Budgeting;Socialism (Theory and Philosophy);Income Inequality;United States Politics and Government;United States',
#    'column': None,
#    'byline': 'By Michelle Alexander',
#    'type': 'Article',
#    'title': 'America, This Is Your Chance',
#    'abstract': 'We must get it right this time or risk losing our democracy forever.',
#    'des_facet': ['George Floyd Protests (2020)',
#     'Black Lives Matter Movement',
#     'Police Brutality, Misconduct and Shootings',
#     'Criminal Justice',
#     'Black People',
#     'Race and Ethnicity',
#     'Budgets and Budgeting',
#     'Socialism (Theory and Philosophy)',
#     'Income Inequality',
#     'United States Politics and Government'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['United States'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters marched through New York City again on Wednesday in response to the police killing of George Floyd.',
#      'copyright': 'Ashley Gilbertson for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/08/opinion/08Alexander/merlin_173231205_9d67dc73-8e66-44d8-a7fd-2de7c52043b4-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/08/opinion/08Alexander/merlin_173231205_9d67dc73-8e66-44d8-a7fd-2de7c52043b4-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/08/opinion/08Alexander/merlin_173231205_9d67dc73-8e66-44d8-a7fd-2de7c52043b4-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/1f4c50de-ec2e-5f47-b4d2-65ed33b192d2',
#    'url': 'https://www.nytimes.com/2020/06/15/well/live/breathing-masks-coronavirus.html',
#    'id': 100000007177286,
#    'asset_id': 100000007177286,
#    'source': 'New York Times',
#    'published_date': '2020-06-15',
#    'updated': '2020-06-17 10:39:30',
#    'section': 'Well',
#    'subsection': 'Live',
#    'nytdsection': 'well',
#    'adx_keywords': 'Masks;Protective Clothing and Gear;Nose;Coronavirus (2019-nCoV);Oxygen;Carbon Dioxide;Lungs',
#    'column': None,
#    'byline': 'By Jane E. Brody',
#    'type': 'Article',
#    'title': 'Looking at Masks and Respiratory Health',
#    'abstract': 'Even without a mask as an impediment, many people breathe in ways that compromise their well-being.',
#    'des_facet': ['Masks',
#     'Protective Clothing and Gear',
#     'Nose',
#     'Coronavirus (2019-nCoV)',
#     'Oxygen',
#     'Carbon Dioxide',
#     'Lungs'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Gracia Lam',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/16/well/16SCI-BRODY-art/16SCI-BRODY-art-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/well/16SCI-BRODY-art/16SCI-BRODY-art-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/well/16SCI-BRODY-art/16SCI-BRODY-art-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/d92f4825-5401-5752-8ec7-4c67d6a77edd',
#    'url': 'https://www.nytimes.com/2020/06/09/opinion/us-deficit-coronavirus.html',
#    'id': 100000007176477,
#    'asset_id': 100000007176477,
#    'source': 'New York Times',
#    'published_date': '2020-06-09',
#    'updated': '2020-06-10 18:07:00',
#    'section': 'Opinion',
#    'subsection': '',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'National Debt (US);Federal Budget (US);Federal Taxes (US);United States Politics and Government;United States Economy;Economics (Theory and Philosophy)',
#    'column': None,
#    'byline': 'By Stephanie Kelton',
#    'type': 'Article',
#    'title': 'Learn To Love Trillion-Dollar Deficits',
#    'abstract': 'Our country’s myth about federal debt, explained.',
#    'des_facet': ['National Debt (US)',
#     'Federal Budget (US)',
#     'Federal Taxes (US)',
#     'United States Politics and Government',
#     'United States Economy',
#     'Economics (Theory and Philosophy)'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Nerthuz/iStock, via Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/09/opinion/09Kelton/09Kelton-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/09/opinion/09Kelton/09Kelton-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/09/opinion/09Kelton/09Kelton-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/48bd544b-143a-5060-94a2-856006774d66',
#    'url': 'https://www.nytimes.com/2020/06/09/arts/music/choirs-singing-coronavirus-safe.html',
#    'id': 100000007167126,
#    'asset_id': 100000007167126,
#    'source': 'New York Times',
#    'published_date': '2020-06-09',
#    'updated': '2020-06-12 16:05:08',
#    'section': 'Arts',
#    'subsection': 'Music',
#    'nytdsection': 'arts',
#    'adx_keywords': 'Music;Coronavirus (2019-nCoV);Coronavirus Reopenings;Quarantines;Research;Content Type: Service;Coronavirus Risks and Safety Concerns;Bavarian Radio Chorus;Ludwig Maximilian University',
#    'column': None,
#    'byline': 'By Alex Marshall',
#    'type': 'Article',
#    'title': 'When Will It Be Safe to Sing Together Again?',
#    'abstract': 'Choirs have been linked to several coronavirus outbreaks. And some scientists are skeptical about efforts to bring them back with protective measures.',
#    'des_facet': ['Music',
#     'Coronavirus (2019-nCoV)',
#     'Coronavirus Reopenings',
#     'Quarantines',
#     'Research',
#     'Content Type: Service',
#     'Coronavirus Risks and Safety Concerns'],
#    'org_facet': ['Bavarian Radio Chorus', 'Ludwig Maximilian University'],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'A singer of the Bavarian Radio Chorus sings after inhaling vapor from an e-cigarette.',
#      'copyright': 'Bayerischer Rundfunk',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/10/arts/03choirs2/03choirs2-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/10/arts/03choirs2/03choirs2-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/10/arts/03choirs2/03choirs2-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/96f46bc6-160a-5432-ab73-eb4c1e105251',
#    'url': 'https://www.nytimes.com/2020/06/12/opinion/sunday/black-america-racism-refugee.html',
#    'id': 100000007186177,
#    'asset_id': 100000007186177,
#    'source': 'New York Times',
#    'published_date': '2020-06-12',
#    'updated': '2020-06-14 20:23:48',
#    'section': 'Opinion',
#    'subsection': 'Sunday Review',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'Black People;Discrimination;George Floyd Protests (2020);Black Lives Matter Movement;Civil Rights and Liberties;Coronavirus (2019-nCoV);United States;Trinidad and Tobago',
#    'column': None,
#    'byline': 'By Tiffanie Drayton',
#    'type': 'Article',
#    'title': 'I’m a Black American. I Had to Get Out.',
#    'abstract': 'The racism was too much. I fled.',
#    'des_facet': ['Black People',
#     'Discrimination',
#     'George Floyd Protests (2020)',
#     'Black Lives Matter Movement',
#     'Civil Rights and Liberties',
#     'Coronavirus (2019-nCoV)'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': ['United States', 'Trinidad and Tobago'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Toyin Ojih Odutola. Courtesy of the artist and Jack Shainman Gallery, New York.',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/14/opinion/sunday/14Drayton/14Drayton-thumbStandard-v3.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/14/opinion/sunday/14Drayton/14Drayton-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/14/opinion/sunday/14Drayton/14Drayton-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/0d255584-a7e4-5f45-a551-c367b7af25e7',
#    'url': 'https://www.nytimes.com/2020/06/09/us/black-cowboys-protests-compton.html',
#    'id': 100000007180041,
#    'asset_id': 100000007180041,
#    'source': 'New York Times',
#    'published_date': '2020-06-09',
#    'updated': '2020-06-12 13:37:30',
#    'section': 'U.S.',
#    'subsection': '',
#    'nytdsection': 'u.s.',
#    'adx_keywords': 'George Floyd Protests (2020);Black Lives Matter Movement;Black People;Cowboys and Cowgirls;Compton Cowboys;Compton (Calif)',
#    'column': None,
#    'byline': 'By Walter Thompson-Hernández and Kayla Reefer',
#    'type': 'Article',
#    'title': 'Evoking History, Black Cowboys Take to the Streets',
#    'abstract': 'The presence of black cowboys and cowgirls at protests is a reclaiming of the traditional role of mounted riders in demonstrations in urban communities.',
#    'des_facet': ['George Floyd Protests (2020)',
#     'Black Lives Matter Movement',
#     'Black People',
#     'Cowboys and Cowgirls'],
#    'org_facet': ['Compton Cowboys'],
#    'per_facet': [],
#    'geo_facet': ['Compton (Calif)'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Kayla Reefer for The New York Times',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/09/us/09unrest-cowboys-socialcard/09unrest-cowboys-socialcard-thumbStandard-v2.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/09/us/09unrest-cowboys-socialcard/09unrest-cowboys-socialcard-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/09/us/09unrest-cowboys-socialcard/09unrest-cowboys-socialcard-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/ff3a7f8c-2e43-502c-871c-b5d91b67fa86',
#    'url': 'https://www.nytimes.com/2020/06/16/health/coronavirus-toilets-flushing.html',
#    'id': 100000007193321,
#    'asset_id': 100000007193321,
#    'source': 'New York Times',
#    'published_date': '2020-06-16',
#    'updated': '2020-06-17 13:30:27',
#    'section': 'Health',
#    'subsection': '',
#    'nytdsection': 'health',
#    'adx_keywords': 'Coronavirus (2019-nCoV);Bathrooms and Toilets;Coronavirus Risks and Safety Concerns;Research;Hygiene and Cleanliness;Feces;your-feed-science;your-feed-health;Wang, Ji-Xiang;Physics of Fluids (Journal)',
#    'column': None,
#    'byline': 'By Knvul Sheikh',
#    'type': 'Article',
#    'title': 'Flushing the Toilet May Fling Coronavirus Aerosols All Over',
#    'abstract': 'A new study shows how turbulence from a toilet bowl can create a large plume that is potentially infectious to a bathroom’s next visitor.',
#    'des_facet': ['Coronavirus (2019-nCoV)',
#     'Bathrooms and Toilets',
#     'Coronavirus Risks and Safety Concerns',
#     'Research',
#     'Hygiene and Cleanliness',
#     'Feces',
#     'your-feed-science',
#     'your-feed-health'],
#    'org_facet': ['Physics of Fluids (Journal)'],
#    'per_facet': ['Wang, Ji-Xiang'],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'John Greim/LightRocket, via Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/16/science/16VIRUS-FLUSH/16VIRUS-FLUSH-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/science/16VIRUS-FLUSH/16VIRUS-FLUSH-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/science/16VIRUS-FLUSH/16VIRUS-FLUSH-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/cd0484f3-9d9d-5ab9-b053-0d44ea2ddc6f',
#    'url': 'https://www.nytimes.com/2020/06/13/opinion/sunday/black-politicians-george-floyd-protests.html',
#    'id': 100000007181241,
#    'asset_id': 100000007181241,
#    'source': 'New York Times',
#    'published_date': '2020-06-13',
#    'updated': '2020-06-14 16:57:34',
#    'section': 'Opinion',
#    'subsection': 'Sunday Review',
#    'nytdsection': 'opinion',
#    'adx_keywords': 'Black People;George Floyd Protests (2020);Black Lives Matter Movement;United States Politics and Government',
#    'column': None,
#    'byline': 'By Keeanga-Yamahtta Taylor',
#    'type': 'Article',
#    'title': 'The End of Black Politics',
#    'abstract': 'Black leaders regularly fail to rise to the challenges that confront young people.',
#    'des_facet': ['Black People',
#     'George Floyd Protests (2020)',
#     'Black Lives Matter Movement',
#     'United States Politics and Government'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Diana Ejaita',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/14/opinion/sunday/14Taylor/14Taylor-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/14/opinion/sunday/14Taylor/14Taylor-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/14/opinion/sunday/14Taylor/14Taylor-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/476351bb-2b63-5637-9f20-3a1c0ddcb35a',
#    'url': 'https://www.nytimes.com/2020/06/11/travel/recreational-vehicles-RV-pandemic.html',
#    'id': 100000007159817,
#    'asset_id': 100000007159817,
#    'source': 'New York Times',
#    'published_date': '2020-06-11',
#    'updated': '2020-06-15 12:23:21',
#    'section': 'Travel',
#    'subsection': '',
#    'nytdsection': 'travel',
#    'adx_keywords': 'Recreational Vehicles;Travel and Vacations;States (US);Camps and Camping;Vans;Road Trips;Quarantine (Life and Culture);ABERCROMBIE & KENT;Cruise America;Kampgrounds of America',
#    'column': None,
#    'byline': 'By Elaine Glusac',
#    'type': 'Article',
#    'title': 'Worried About Social Distancing When Traveling? Join the Crowd and Rent an R.V.',
#    'abstract': 'Recreational vehicles were gaining in popularity before the pandemic. Now, with travel restrictions loosening, a surge of travelers is drawn to the relative solitude that R.V.s offer.',
#    'des_facet': ['Recreational Vehicles',
#     'Travel and Vacations',
#     'States (US)',
#     'Camps and Camping',
#     'Vans',
#     'Road Trips',
#     'Quarantine (Life and Culture)'],
#    'org_facet': ['ABERCROMBIE & KENT',
#     'Cruise America',
#     'Kampgrounds of America'],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Many travelers are finding social distancing is easy in an R.V. Above, on the road in Utah with an Airstream.\xa0',
#      'copyright': 'Anthony Tori',
#      'approved_for_syndication': 0,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/03/travel/11RV-Travel-1/oakImage-1591204029286-thumbStandard.png',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/03/travel/11RV-Travel-1/oakImage-1591204029286-mediumThreeByTwo210.png',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/03/travel/11RV-Travel-1/oakImage-1591204029286-mediumThreeByTwo440.png',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/d674dde3-991c-5d60-b678-5e1a88c1c198',
#    'url': 'https://www.nytimes.com/2020/06/14/nyregion/central-park-amy-cooper-christian-racism.html',
#    'id': 100000007163605,
#    'asset_id': 100000007163605,
#    'source': 'New York Times',
#    'published_date': '2020-06-14',
#    'updated': '2020-06-17 05:05:23',
#    'section': 'New York',
#    'subsection': '',
#    'nytdsection': 'new york',
#    'adx_keywords': 'Black Lives Matter Movement;George Floyd Protests (2020);Race and Ethnicity;Discrimination;Black People;Cooper, Christian (Birder);Cooper, Amy (May 25, 2020 Central Park Incident);Central Park (Manhattan, NY)',
#    'column': None,
#    'byline': 'By Sarah Maslin Nir',
#    'type': 'Article',
#    'title': 'How 2 Lives Collided in Central Park, Rattling the Nation',
#    'abstract': 'The inside story of the black birder and the white woman who called the police on him. Their encounter stirred wrenching conversations about racism and white privilege.',
#    'des_facet': ['Black Lives Matter Movement',
#     'George Floyd Protests (2020)',
#     'Race and Ethnicity',
#     'Discrimination',
#     'Black People'],
#    'org_facet': [],
#    'per_facet': ['Cooper, Christian (Birder)',
#     'Cooper, Amy (May 25, 2020 Central Park Incident)'],
#    'geo_facet': ['Central Park (Manhattan, NY)'],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': '',
#      'copyright': 'Brittainy Newman/The New York Times; Alison Faircloth',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/16/nyregion/00CENTRALPARK-TWOLIVES-top/00CENTRALPARK-TWOLIVES-top-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/nyregion/00CENTRALPARK-TWOLIVES-top/00CENTRALPARK-TWOLIVES-top-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/16/nyregion/00CENTRALPARK-TWOLIVES-top/00CENTRALPARK-TWOLIVES-top-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/f9777004-2651-556d-86de-0e409359f58f',
#    'url': 'https://www.nytimes.com/2020/06/16/us/coronavirus-inmates-prisons-jails.html',
#    'id': 100000007104159,
#    'asset_id': 100000007104159,
#    'source': 'New York Times',
#    'published_date': '2020-06-16',
#    'updated': '2020-06-17 13:33:02',
#    'section': 'U.S.',
#    'subsection': '',
#    'nytdsection': 'u.s.',
#    'adx_keywords': 'Coronavirus (2019-nCoV);Prisons and Prisoners;Tests (Medical);States (US)',
#    'column': None,
#    'byline': 'By Timothy Williams, Libby Seline and Rebecca Griesbach',
#    'type': 'Article',
#    'title': 'Coronavirus Cases Rise Sharply in Prisons Even as They Plateau Nationwide',
#    'abstract': 'Prison officials have been reluctant to do widespread virus testing even as infection rates are escalating.',
#    'des_facet': ['Coronavirus (2019-nCoV)',
#     'Prisons and Prisoners',
#     'Tests (Medical)',
#     'States (US)'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Protesters held a rally to bring awareness about the spread of the coronavirus inside the Marion Correctional Institution in Marion, Ohio, in May.',
#      'copyright': 'Megan Jelinger/Agence France-Presse — Getty Images',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/10/us/00virus-prisons01/00virus-prisons01-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/10/us/00virus-prisons01/00virus-prisons01-mediumThreeByTwo210.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/10/us/00virus-prisons01/00virus-prisons01-mediumThreeByTwo440.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0},
#   {'uri': 'nyt://article/ae7db073-c6a8-5db8-851b-5807d195ddd3',
#    'url': 'https://www.nytimes.com/2020/06/10/upshot/dentists-coronavirus-economic-indicator.html',
#    'id': 100000007179933,
#    'asset_id': 100000007179933,
#    'source': 'New York Times',
#    'published_date': '2020-06-10',
#    'updated': '2020-06-16 12:05:31',
#    'section': 'The Upshot',
#    'subsection': '',
#    'nytdsection': 'the upshot',
#    'adx_keywords': 'Teeth and Dentistry;Coronavirus Reopenings;United States Economy;Protective Clothing and Gear;Coronavirus (2019-nCoV);Shutdowns (Institutional);Coronavirus Aid, Relief, and Economic Security Act (2020)',
#    'column': None,
#    'byline': 'By Sarah Kliff',
#    'type': 'Article',
#    'title': 'How’s the Economy Doing? Watch the Dentists',
#    'abstract': 'A crucial indicator of whether Americans feel safe returning to normal activities.',
#    'des_facet': ['Teeth and Dentistry',
#     'Coronavirus Reopenings',
#     'United States Economy',
#     'Protective Clothing and Gear',
#     'Coronavirus (2019-nCoV)',
#     'Shutdowns (Institutional)',
#     'Coronavirus Aid, Relief, and Economic Security Act (2020)'],
#    'org_facet': [],
#    'per_facet': [],
#    'geo_facet': [],
#    'media': [{'type': 'image',
#      'subtype': 'photo',
#      'caption': 'Installing a crown at a dental office in Vinton, Iowa, last month. In many places, dentists have gone back to work.',
#      'copyright': 'Andy Abeyta/The Gazette, via Associated Press',
#      'approved_for_syndication': 1,
#      'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/13/upshot/13up-coronavirus-dentist/10up-coronavirus-dentist-thumbStandard.jpg',
#        'format': 'Standard Thumbnail',
#        'height': 75,
#        'width': 75},
#       {'url': 'https://static01.nyt.com/images/2020/06/13/upshot/13up-coronavirus-dentist/10up-coronavirus-dentist-mediumThreeByTwo210-v2.jpg',
#        'format': 'mediumThreeByTwo210',
#        'height': 140,
#        'width': 210},
#       {'url': 'https://static01.nyt.com/images/2020/06/13/upshot/13up-coronavirus-dentist/10up-coronavirus-dentist-mediumThreeByTwo440-v2.jpg',
#        'format': 'mediumThreeByTwo440',
#        'height': 293,
#        'width': 440}]}],
#    'eta_id': 0}]}

# %%
# we want to look at one article from the 20 returned
# all the information is stored in the key, 'results'
# results maps to a list of dictionaries that contain the article metadata
# so you will need to use an index number to access the dictionary you want

# %%
article = data['results'][1]
# print(article)
article


# article['url']
# print(url)
# Out:
# {'uri': 'nyt://article/0582a540-250c-5cfa-abd7-655454d01717',
#  'url': 'https://www.nytimes.com/2020/06/12/arts/music/bob-dylan-rough-and-rowdy-ways.html',
#  'id': 100000007177221,
#  'asset_id': 100000007177221,
#  'source': 'New York Times',
#  'published_date': '2020-06-12',
#  'updated': '2020-06-15 18:43:53',
#  'section': 'Arts',
#  'subsection': 'Music',
#  'nytdsection': 'arts',
#  'adx_keywords': 'Folk Music;Pop and Rock Music;Dylan, Bob',
#  'column': None,
#  'byline': 'By Douglas Brinkley',
#  'type': 'Article',
#  'title': 'Bob Dylan Has a Lot on His Mind',
#  'abstract': 'In a rare interview, the Nobel Prize winner discusses mortality, drawing inspiration from the past, and his new album, “Rough and Rowdy Ways.”',
#  'des_facet': ['Folk Music', 'Pop and Rock Music'],
#  'org_facet': [],
#  'per_facet': ['Dylan, Bob'],
#  'geo_facet': [],
#  'media': [{'type': 'image',
#    'subtype': 'photo',
#    'caption': 'Bob Dylan&rsquo;s &ldquo;Rough and Rowdy Ways&rdquo; is his first album of original songs since 2012.',
#    'copyright': 'Kevin Winter/Getty Images',
#    'approved_for_syndication': 1,
#    'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75},
#     {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210},
#     {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440}]}],
#  'eta_id': 0}

# %%
# get url
article['url']
# Out:
# 'https://www.nytimes.com/2020/06/12/arts/music/bob-dylan-rough-and-rowdy-ways.html'

# %%
# get title
article['title']
# Out:
# 'Bob Dylan Has a Lot on His Mind'

# %%
# get byline
article['byline']
# Out:
# 'By Douglas Brinkley'

# %%
# get description tags and iterate through them
tags = article['des_facet']
for tag in tags:
    print(tag)
# Out:
# Folk Music
# Pop and Rock Music

# %%
# add a key read_or_not with a boolean value

# check to see that 'read_or_not' has been added
article['read_or_not']=True
print(article)
# Out:
# {'uri': 'nyt://article/0582a540-250c-5cfa-abd7-655454d01717', 'url': 'https://www.nytimes.com/2020/06/12/arts/music/bob-dylan-rough-and-rowdy-ways.html', 'id': 100000007177221, 'asset_id': 100000007177221, 'source': 'New York Times', 'published_date': '2020-06-12', 'updated': '2020-06-15 18:43:53', 'section': 'Arts', 'subsection': 'Music', 'nytdsection': 'arts', 'adx_keywords': 'Folk Music;Pop and Rock Music;Dylan, Bob', 'column': None, 'byline': 'By Douglas Brinkley', 'type': 'Article', 'title': 'Bob Dylan Has a Lot on His Mind', 'abstract': 'In a rare interview, the Nobel Prize winner discusses mortality, drawing inspiration from the past, and his new album, “Rough and Rowdy Ways.”', 'des_facet': ['Folk Music', 'Pop and Rock Music'], 'org_facet': [], 'per_facet': ['Dylan, Bob'], 'geo_facet': [], 'media': [{'type': 'image', 'subtype': 'photo', 'caption': 'Bob Dylan&rsquo;s &ldquo;Rough and Rowdy Ways&rdquo; is his first album of original songs since 2012.', 'copyright': 'Kevin Winter/Getty Images', 'approved_for_syndication': 1, 'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-thumbStandard.jpg', 'format': 'Standard Thumbnail', 'height': 75, 'width': 75}, {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo210.jpg', 'format': 'mediumThreeByTwo210', 'height': 140, 'width': 210}, {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo440.jpg', 'format': 'mediumThreeByTwo440', 'height': 293, 'width': 440}]}], 'eta_id': 0, 'read_or_not': True}

# %%
# let's remove the two keys with empty lists: 'org_facet', 'per_facet'
# remove key/value using pop() & keyword del

# make sure the keys are removed!
article.pop('org_facet')
article.pop('geo_facet')
article
# Out:
# {'uri': 'nyt://article/0582a540-250c-5cfa-abd7-655454d01717',
#  'url': 'https://www.nytimes.com/2020/06/12/arts/music/bob-dylan-rough-and-rowdy-ways.html',
#  'id': 100000007177221,
#  'asset_id': 100000007177221,
#  'source': 'New York Times',
#  'published_date': '2020-06-12',
#  'updated': '2020-06-15 18:43:53',
#  'section': 'Arts',
#  'subsection': 'Music',
#  'nytdsection': 'arts',
#  'adx_keywords': 'Folk Music;Pop and Rock Music;Dylan, Bob',
#  'column': None,
#  'byline': 'By Douglas Brinkley',
#  'type': 'Article',
#  'title': 'Bob Dylan Has a Lot on His Mind',
#  'abstract': 'In a rare interview, the Nobel Prize winner discusses mortality, drawing inspiration from the past, and his new album, “Rough and Rowdy Ways.”',
#  'des_facet': ['Folk Music', 'Pop and Rock Music'],
#  'per_facet': ['Dylan, Bob'],
#  'media': [{'type': 'image',
#    'subtype': 'photo',
#    'caption': 'Bob Dylan&rsquo;s &ldquo;Rough and Rowdy Ways&rdquo; is his first album of original songs since 2012.',
#    'copyright': 'Kevin Winter/Getty Images',
#    'approved_for_syndication': 1,
#    'media-metadata': [{'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-thumbStandard.jpg',
#      'format': 'Standard Thumbnail',
#      'height': 75,
#      'width': 75},
#     {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo210.jpg',
#      'format': 'mediumThreeByTwo210',
#      'height': 140,
#      'width': 210},
#     {'url': 'https://static01.nyt.com/images/2020/06/14/arts/14dylan1/merlin_146478750_0a7f707b-ed5c-4046-a922-d33d68db402d-mediumThreeByTwo440.jpg',
#      'format': 'mediumThreeByTwo440',
#      'height': 293,
#      'width': 440}]}],
#  'eta_id': 0,
#  'read_or_not': True}

# %%
# use IPython & the media metadata to display an image from the returned data
# IPython (Interactive Python) is basically a command shell for interactive computing
# here we are using it to import the display module and Image class so we can see our image within our notebook
from IPython.display import Image

# Image takes three arguments: the image path/url, width, and height
# we are going to fetch all of those data from above like we did for article url, title, and byline
img=article['media'][0]['media-metadata'][0]
imgurl=img['url']
imgurl
Image(imgurl, width=img['width'], height=img['height']) # plug in the correct variables in order
